# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df["Cabin"].isnull().sum
# Out:
# <bound method Series.sum of 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool>

# %%
df["PassengerId"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Survived"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Pclass"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Name"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Sex"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(177)

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["SibSp"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Parch"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Ticket"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Fare"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Cabin"].isnull().sum()
# Out:
# np.int64(687)

# %%
df["Embarked"].isnull().sum()
# Out:
# np.int64(2)

# %%
df["Embarked"].dtype
# Out:
# dtype('O')

# %%
df["Embarked"]=df["Embarked"].fillna(df["Embarked"].mode()[0])

# %%
df["Embarked"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Cabin"].dtype
# Out:
# dtype('O')

# %%
df["Cabin"]=df["Cabin"].fillna(df["Cabin"].mode()[0])

# %%
df["Cabin"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Ticket"].dtype
# Out:
# dtype('O')

# %%
df["Cabin"]
# Out:
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %%
df["Fare"].isnull().sum()
# Out:
# np.int64(0)

# %%
input=df.drop("Fare",axis='columns')

# %%
input.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket    Cabin Embarked
# 0      0         A/5 21171  B96 B98        S
# 1      0          PC 17599      C85        C
# 2      0  STON/O2. 3101282  B96 B98        S
# 3      0            113803     C123        S
# 4      0            373450  B96 B98        S

# %%
output=df["Fare"]

# %%
output.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
output.shape
# Out:
# (891,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    input, output, test_size=0.2, random_state=42
)

# %%
df["Embarked"].nunique()
# Out:
# 3

# %%
input.drop("Name",axis=1,inplace=True)

# %%
input.shape
# Out:
# (891, 10)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["Sex_en"]=le.fit_transform(df["Sex"])

# %%
df["Sex_en"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex_en, Length: 891, dtype: int64

# %%
df["Ticket_en"]=le.fit_transform(df["Ticket"])

# %%
df["Cabin_en"]=le.fit_transform(df["Cabin"])

# %%
df["Embarked_en"]=le.fit_transform(df["Embarked"])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  Sex_en  Ticket_en  \
# 0      0         A/5 21171   7.2500  B96 B98        S       1        523
# 1      0          PC 17599  71.2833      C85        C       0        596
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S       0        669
# ...

# %%
df.drop(["Name","Sex","Ticket","Cabin","Embarked"],axis=1,inplace=True)

# %%
out=df["Fare"]

# %%
out.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
df.drop(["Fare"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch  Sex_en  Ticket_en  \
# 0            1         0       3  22.0      1      0       1        523
# 1            2         1       1  38.0      1      0       0        596
# 2            3         1       3  26.0      0      0       0        669
# 3            4         1       1  35.0      1      0       0         49
# 4            5         0       3  35.0      0      0       1        472
#
#    Cabin_en  Embarked_en
# 0        47            2
# 1        81            0
# 2        47            2
# 3        55            2
# 4        47            2

# %%
out.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    df, out, test_size=0.2, random_state=42
)

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(x_test,y_test)
# Out:
# -0.14840385591210348

# %%
model.predict(x_test)
# Out:
# array([ 15.2458,  10.5   ,   7.05  ,  33.    ,  14.4542, 133.65  ,
#          7.75  ,  18.    ,   6.75  , 151.55  ,  52.    ,   8.05  ,
#         25.4667,   7.2292,  13.    ,  90.    ,  53.1   ,   7.6292,
#         13.5   ,  33.5   ,   7.8958,  30.5   ,   9.825 ,  16.1   ,
#          8.05  ,  21.075 ,  27.7208,  13.    ,  21.075 ,   7.8542,
#          7.8958,   7.775 ,  79.2   ,   7.925 ,   8.05  ,  14.4542,
#         35.5   ,   7.75  ,  57.    ,   7.8958,  73.5   ,  16.1   ,
#          8.3625,   8.05  ,  15.2458,  23.45  ,   7.05  ,   6.8583,
#          7.05  , 151.55  ,  19.2583,  77.9583,  31.275 , 120.    ,
#          7.75  , 120.    ,  10.5   ,  79.2   ,  10.5   ,   7.8792,
#          7.775 ,  14.5   ,  26.    ,  50.    ,   7.75  ,  10.5   ,
#         10.5   ,   8.6625,   7.2292,  78.2667,  14.5   , 262.375 ,
#         29.7   , 512.3292,   7.8542,  17.4   ,   8.05  , 110.8833,
#         13.    ,   8.4042,  39.6875,  10.5   ,  83.1583,   7.7375,
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch  Sex_en  Ticket_en  \
# 0            1         0       3  22.0      1      0       1        523
# 1            2         1       1  38.0      1      0       0        596
# 2            3         1       3  26.0      0      0       0        669
# 3            4         1       1  35.0      1      0       0         49
# 4            5         0       3  35.0      0      0       1        472
#
#    Cabin_en  Embarked_en
# 0        47            2
# 1        81            0
# 2        47            2
# 3        55            2
# 4        47            2

# %%
model.predict([[4,1,1,35.0,1,0,0,29,55,2]])
# Out:
# C:\Users\Kotha Alekya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([53.1])
